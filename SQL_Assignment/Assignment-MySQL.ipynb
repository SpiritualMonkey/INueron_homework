# %% [raw]
# 1 . take a data set from attached URL https://archive.ics.uci.edu/ml/datasets/Car+Evaluation
# 2 . create a database called as cardataset
# 3 . create a table called as car with a column name given in dataset description
# 4 . Dump all the data into car table
# 5 . try to check weather all the data is aviable inside your table or not
# 6 . try to group all the data with COL1 AND count occurences of each and every record based on col1 value
# 7 . Try to filter a record where col 3 value will be 4 .
# 8.  Try to update a col 3 value with 8 whereever you have value equal to 2
# 9 . try to delete table
# 10. Try to delete database

# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = 'localhost',user = 'root',passwd='Fuckyoutaliban@1996')

# %%
mydb

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('rohandb',),
#  ('sys',),
#  ('testsudhineuron',)]

# %%
cursor = mydb.cursor()

# %% [markdown]
# # create a database called as cardataset

# %%
# cursor.execute("create database cardataset")

# %% [markdown]
# # create a table called as cars with a column name given in dataset description

# %%
# cursor.execute("create table cardataset.car(buying varchar(100),maint varchar(100), doors int, persons int,lug_boot varchar(100),safety  varchar(100),class varchar(100))")

# %%
cursor.execute("use cardataset")
cursor.execute('show tables')
cursor.fetchall()
# Out:
# [('car',), ('cars',)]

# %%
cursor.execute("select * from cardataset.car")
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', 2, 2, 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'big', 'high', 'unacc')]

# %%
# import csv
# with open('car.data','r') as f:
#     gdata = csv.reader(f)
#     for i in gdata:
#         #print(str(i[0]))
#         #print("insert into carsdataset.cars (buying, maint, doors, persons, lug_boot, safety, class) values({},{},{},{},{},{},{})".format(i[0],i[1],i[2],i[3],i[4],i[5],i[6]))
#         cursor.execute("insert into cardataset.car (buying, maint, doors, persons, lug_boot, safety, class) values(%s,%s,%s,%s,%s,%s,%s)",[str(i[0]),str(i[1]),i[2],i[3],str(i[4]),str(i[5]),str(i[6])])
# mydb.commit()

# %%
# with open('car.data', 'r') as f:
#     car_data = csv.reader(f, delimiter = '\n')
#     for i in car_data:
#         row_data = tuple(i[0].split(','))
#         query = "INSERT INTO cardataset.car VALUES {}".format(row_data)
#         cursor.execute(query)
# mydb.commit()

# %%
cursor = mydb.cursor()
cursor.execute("use cardataset")
cursor.execute('show tables')
cursor.fetchall()
# Out:
# [('car',), ('cars',)]

# %%
cursor.execute("select * from cardataset.car")
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', 2, 2, 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 2, 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', 2, 4, 'big', 'high', 'unacc')]

# %%
# cursor.execute("create table cardataset.cars(buying varchar(100),maint varchar(100), doors varchar(100), persons varchar(100),lug_boot varchar(100),safety  varchar(100),class varchar(100))")

# %% [markdown]
# # Dump all the data into car table

# %%
import csv

# %%
with open('car.data','r') as f:
    gdata = csv.reader(f)
    for i in gdata:
        row_data = tuple(i)
        cursor.execute("INSERT INTO cardataset.cars VALUES {}".format(row_data))                  
mydb.commit()

# %% [markdown]
# # try to check weather all the data is aviable inside your table or not

# %%
cursor = mydb.cursor()
cursor.execute("use cardataset")
cursor.execute('show tables')
cursor.fetchall()
# Out:
# [('car',), ('cars',)]

# %%
cursor.execute("select * from cardataset.cars")
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %% [markdown]
# # try to group all the data with COL1 AND count occurences of each and every record based on col1 value

# %%
cursor.execute("select buying,count(*) from cardataset.cars group by buying" )
cursor.fetchall()
# Out:
# [('vhigh', 432), ('high', 432), ('med', 432), ('low', 432)]

# %% [markdown]
# # Try to filter a record where col 3 value will be 4

# %%
cursor.execute("select * from cardataset.cars where doors ='4' " )
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %% [markdown]
# # Try to update a col 3 value with 8 whereever you have value equal to 2

# %%
cursor.execute("select * from cardataset.cars where doors ='2' " )
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute("update cardataset.cars SET doors='8' where doors ='2' " )
mydb.commit()

# %%
cursor.execute("select * from cardataset.cars where doors ='2' " )
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select * from cardataset.cars where doors ='8' " )
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '8', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '8', '4', 'big', 'med', 'unacc'),
# ...

# %% [markdown]
# # try to delete table

# %%
cursor.execute("use cardataset")
cursor.execute('show tables')
cursor.fetchall()
# Out:
# [('car',), ('cars',)]

# %%
cursor.execute("drop table cardataset.car")
mydb.commit()

# %%
cursor.execute("use cardataset")
cursor.execute('show tables')
cursor.fetchall()
# Out:
# [('cars',)]

# %% [markdown]
# # Try to delete database

# %%
cursor.execute("create database rohan")
cursor = mydb.cursor()
cursor.execute("show databases")
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('rohan',),
#  ('rohandb',),
#  ('sys',),
#  ('testsudhineuron',)]

# %%
cursor.execute("drop database rohan")
mydb.commit()
cursor = mydb.cursor()
cursor.execute("show databases")
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('rohandb',),
#  ('sys',),
#  ('testsudhineuron',)]
